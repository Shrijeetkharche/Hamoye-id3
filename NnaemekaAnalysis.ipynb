# %% [markdown]
# ![Screenshot from 2022-02-21 16-14-09.png](data:image/png;base64,...)

# %% [markdown]
# From this plot, we can see that Nordrhein-Westfalen(NW) has the most deaths in Germany before and during covid.
#
# This might be due to the population of NW.
# A plot of population by states will help

# %% [markdown]
# We can see from this plot also that the deaths in Age group 0 - 65 did not see significant changes from before covid to during covid
#
# The ages of 65+ so a drastic increase in deaths during the covid outbreak.
#
# This might be due to a population of more elderly people i.e these states might more elderly people than youths.

# %% [markdown]
# A plot of deaths by age during and after covid will help clarify
